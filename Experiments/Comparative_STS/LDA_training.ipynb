# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

feature_names = pd.read_csv('../../Dataset/STS/Data_Names.csv')
header = feature_names['features'].tolist()
#set header for the dataset
dataset = pd.read_csv('../../Dataset/STS/Data_STS.csv')
dataset.columns = header

# %%
# Separate the features and the target
X = dataset.iloc[:, :-1]  # everything except the last column (fatigue_level)
y = dataset.iloc[:, -1]  # fatigue_level
X
# Out:
#      Stand-to-stand time  Sit-to-stand time  Stand-to-sit time  \
# 0                1.14940            1.02190            1.04600
# 1                1.21500            1.09940            1.08040
# 2                1.07120            0.99290            1.09650
# 3                1.31060            1.37710            1.21950
# 4                1.27670            1.22980            1.26430
# ..                   ...                ...                ...
# 654              0.95064            0.99793            0.84473
# 655              0.94578            0.98939            0.83705
# 656              1.61660            1.70770            1.46810
# 657              1.61810            1.92470            1.47300
# 658              1.70650            2.13250            1.59530
#
#      M_hip vertical range  M_hip depth range  M_hip max vertical velocity  \
# 0                 1.01510            0.96060                      0.98215
# 1                 0.87648            0.89024                      0.99210
# 2                 0.89684            0.95366                      1.00890
# 3                 1.08700            1.10530                      1.00650
# 4                 1.12390            1.15170                      0.95774
# ..                    ...                ...                          ...
# 654               1.10850            1.10370                      1.06350
# 655               1.10750            1.10360                      1.03660
# 656               1.03850            1.00710                      0.79126
# 657               0.41024            0.50380                      0.79675
# 658               1.05620            1.05800                      0.93281
#
#      M_hip min vertical velocity  M_hip max depth velocity  \
# 0                        1.31830                   0.91062
# 1                        1.31770                   0.93530
# 2                        1.12060                   0.95903
# 3                        1.45650                   1.07270
# 4                        1.39200                   1.03950
# ..                           ...                       ...
# 654                      1.27150                   1.02770
# 655                      1.28160                   0.99205
# 656                      0.88634                   1.05220
# 657                      1.28790                   0.67985
# 658                      1.21390                   1.06370
#
#      M_hip min depth velocity  Knee flexo-extension range  ...  \
# 0                     0.92036                     1.00250  ...
# 1                     0.92490                     0.98812  ...
# 2                     0.93991                     1.06500  ...
# 3                     1.15530                     1.07220  ...
# 4                     1.06770                     1.00600  ...
# ..                        ...                         ...  ...
# 654                   1.08340                     1.12840  ...
# 655                   1.09530                     1.05480  ...
# 656                   1.01580                     0.85009  ...
# 657                   0.25566                     1.14970  ...
# 658                   1.13900                     0.66826  ...
#
#      M_shoulder max vertical velocity  M_shoulder min vertical velocity  \
# 0                            0.936620                           0.97932
# 1                            0.862600                           0.94320
# 2                            0.870610                           0.97629
# 3                            1.096400                           1.14290
# 4                            0.988140                           1.08630
# ..                                ...                               ...
# 654                          1.053800                           1.02760
# 655                          1.023400                           0.98703
# 656                          0.044172                           1.02330
# 657                          1.050600                           0.74147
# 658                          1.107600                           1.08640
#
#      M_shoulder max depth velocity  Spine flexo-extension range  \
# 0                          1.00380                      1.21780
# 1                          1.07840                      1.35230
# 2                          1.03280                      1.30740
# 3                          0.94031                      1.42700
# 4                          1.15530                      1.51170
# ..                             ...                          ...
# 654                        0.99755                      1.49780
# 655                        0.94916                      1.47220
# 656                        0.99861                      0.90222
# 657                        0.96685                      1.36710
# 658                        0.84938                      1.36920
#
#      Spine flexo-extension max velocity  Spine flexo-extension min velocity  \
# 0                               0.97569                             0.98219
# 1                               0.95966                             0.94077
# 2                               0.88624                             0.92409
# 3                               1.00150                             1.01930
# 4                               1.03520                             1.01060
# ..                                  ...                                 ...
# 654                             1.15400                             1.05330
# 655                             1.15010                             1.03400
# 656                             1.12840                             1.15320
# 657                             1.16630                             1.17760
# 658                             1.22830                             1.24710
#
#      Spine abduction-adduction range  Spine abduction-adduction max velocity  \
# 0                            0.99926                                 1.28480
# 1                            0.96024                                 1.13840
# 2                            0.94021                                 0.96528
# 3                            1.01720                                 1.41930
# 4                            1.01600                                 1.16110
# ..                               ...                                     ...
# 654                          1.01800                                 1.42000
# 655                          1.03100                                 1.48360
# 656                          0.98197                                 1.00220
# 657                          1.04310                                 1.62930
# 658                          1.06000                                 1.33430
#
#      Spine abduction-adduction min velocity  Heart Rate
# 0                                   1.06290      1.2469
# 1                                   1.01810      1.2537
# 2                                   0.85533      1.2622
# 3                                   1.06020      1.2677
# 4                                   1.04280      1.3722
# ..                                      ...         ...
# 654                                 1.08500      1.7175
# 655                                 1.11320      1.7206
# 656                                 1.23480      1.6203
# 657                                 1.41690      1.8042
# 658                                 1.12830      1.9673
#
# [659 rows x 33 columns]

# %%
# apply LDA
lda = LDA(n_components=None)  # n_components=None 
X_lda = lda.fit(X, y)

# get the feature importance (sum of absolute values of the coefficients)
feature_importances = np.abs(X_lda.coef_).sum(axis=0)

# get the indices of the top 10 features
top_features_indices = np.argsort(feature_importances)[::-1][:10]
top_features = dataset.columns[top_features_indices]
top_features
# Out:
# Index(['Spine abduction-adduction max velocity', 'Ankle flexo-extension range',
#        'Spine abduction-adduction range', 'Hip flexo-extension max velocity',
#        'M_shoulder depth range', 'Hip flexo-extension range',
#        'Spine flexo-extension min velocity', 'Stand-to-stand time',
#        'Spine abduction-adduction min velocity', 'M_hip depth range'],
#       dtype='object')

# %%
# use only the top 10 features apply K-means clustering
X_top_features = X[top_features]
X_top_features
# Out:
#      Spine abduction-adduction max velocity  Ankle flexo-extension range  \
# 0                                   1.28480                      1.28480
# 1                                   1.13840                      1.13840
# 2                                   0.96528                      0.96528
# 3                                   1.41930                      1.41930
# 4                                   1.16110                      1.16110
# ..                                      ...                          ...
# 654                                 1.42000                      1.42000
# 655                                 1.48360                      1.48360
# 656                                 1.00220                      1.00970
# 657                                 1.62930                      1.59150
# 658                                 1.33430                      1.35600
#
#      Spine abduction-adduction range  Hip flexo-extension max velocity  \
# 0                            0.99926                           0.99926
# 1                            0.96024                           0.96024
# 2                            0.94021                           0.94021
# 3                            1.01720                           1.01720
# 4                            1.01600                           1.01600
# ..                               ...                               ...
# 654                          1.01800                           1.01800
# 655                          1.03100                           1.03100
# 656                          0.98197                           0.96650
# 657                          1.04310                           1.05750
# 658                          1.06000                           1.05830
#
#      M_shoulder depth range  Hip flexo-extension range  \
# 0                   0.92684                    0.98219
# 1                   0.94873                    0.94077
# 2                   0.95089                    0.92409
# 3                   0.87146                    1.01930
# 4                   0.87461                    1.01060
# ..                      ...                        ...
# 654                 0.83422                    1.05330
# 655                 0.84454                    1.03400
# 656                 0.81455                    1.15130
# 657                 0.80206                    1.18210
# 658                 0.72491                    1.25780
#
#      Spine flexo-extension min velocity  Stand-to-stand time  \
# 0                               0.98219              1.14940
# 1                               0.94077              1.21500
# 2                               0.92409              1.07120
# 3                               1.01930              1.31060
# 4                               1.01060              1.27670
# ..                                  ...                  ...
# 654                             1.05330              0.95064
# 655                             1.03400              0.94578
# 656                             1.15320              1.61660
# 657                             1.17760              1.61810
# 658                             1.24710              1.70650
#
#      Spine abduction-adduction min velocity  M_hip depth range
# 0                                   1.06290            0.96060
# 1                                   1.01810            0.89024
# 2                                   0.85533            0.95366
# 3                                   1.06020            1.10530
# 4                                   1.04280            1.15170
# ..                                      ...                ...
# 654                                 1.08500            1.10370
# 655                                 1.11320            1.10360
# 656                                 1.23480            1.00710
# 657                                 1.41690            0.50380
# 658                                 1.12830            1.05800
#
# [659 rows x 10 columns]

# %%
# add target colum in the X_top_features
X_top_features['fatigue_level'] = y
X_top_features
# Out:
# C:\Users\shinm\AppData\Local\Temp\ipykernel_36480\4026693783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_top_features['fatigue_level'] = y
#      Spine abduction-adduction max velocity  Ankle flexo-extension range  \
# 0                                   1.28480                      1.28480
# 1                                   1.13840                      1.13840
# 2                                   0.96528                      0.96528
# 3                                   1.41930                      1.41930
# 4                                   1.16110                      1.16110
# ..                                      ...                          ...
# 654                                 1.42000                      1.42000
# 655                                 1.48360                      1.48360
# 656                                 1.00220                      1.00970
# 657                                 1.62930                      1.59150
# 658                                 1.33430                      1.35600
#
#      Spine abduction-adduction range  Hip flexo-extension max velocity  \
# 0                            0.99926                           0.99926
# 1                            0.96024                           0.96024
# 2                            0.94021                           0.94021
# 3                            1.01720                           1.01720
# 4                            1.01600                           1.01600
# ..                               ...                               ...
# 654                          1.01800                           1.01800
# 655                          1.03100                           1.03100
# 656                          0.98197                           0.96650
# 657                          1.04310                           1.05750
# 658                          1.06000                           1.05830
#
#      M_shoulder depth range  Hip flexo-extension range  \
# 0                   0.92684                    0.98219
# 1                   0.94873                    0.94077
# 2                   0.95089                    0.92409
# 3                   0.87146                    1.01930
# 4                   0.87461                    1.01060
# ..                      ...                        ...
# 654                 0.83422                    1.05330
# 655                 0.84454                    1.03400
# 656                 0.81455                    1.15130
# 657                 0.80206                    1.18210
# 658                 0.72491                    1.25780
#
#      Spine flexo-extension min velocity  Stand-to-stand time  \
# 0                               0.98219              1.14940
# 1                               0.94077              1.21500
# 2                               0.92409              1.07120
# 3                               1.01930              1.31060
# 4                               1.01060              1.27670
# ..                                  ...                  ...
# 654                             1.05330              0.95064
# 655                             1.03400              0.94578
# 656                             1.15320              1.61660
# 657                             1.17760              1.61810
# 658                             1.24710              1.70650
#
#      Spine abduction-adduction min velocity  M_hip depth range  fatigue_level
# 0                                   1.06290            0.96060              1
# 1                                   1.01810            0.89024              1
# 2                                   0.85533            0.95366              1
# 3                                   1.06020            1.10530              2
# 4                                   1.04280            1.15170              2
# ..                                      ...                ...            ...
# 654                                 1.08500            1.10370              3
# 655                                 1.11320            1.10360              3
# 656                                 1.23480            1.00710              3
# 657                                 1.41690            0.50380              3
# 658                                 1.12830            1.05800              3
#
# [659 rows x 11 columns]

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
dataset = pd.read_csv('../../Dataset/STS/Top_LDA_dataset.csv')
dataset.iloc[:, -1] = dataset.iloc[:, -1]
X = dataset.iloc[:, :-1]  # Features
y = dataset.iloc[:, -1] -1   # Target
y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 653    2
# 654    2
# 655    2
# 656    2
# 657    2
# Name: 1, Length: 658, dtype: int64

# %%
# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert labels to categorical
y_categorical = to_categorical(y)
y_categorical
# Out:
# array([[1., 0., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        ...,
#        [0., 0., 1.],
#        [0., 0., 1.],
#        [0., 0., 1.]], dtype=float32)

# %%
# Shuffle the data
X_scaled, y_categorical = shuffle(X_scaled, y_categorical, random_state=42)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42)

# Number of unique classes in the target variable
num_classes = y_train.shape[1]


# Building the DNN model
model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],), name='dense_0'),
    Dense(16, activation='relu', name='dense_1'),
    Dense(3, activation='relu', name='dense_2'),
    # Dense(3, activation='relu', name='dense_3'),
    Dense(num_classes, activation='softmax')  # Output layer
])

# %%
# Define the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,  # minimium amount of change to count as an improvement
    patience=100,  # how many epochs to wait before stopping
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# Set the learning rate
learning_rate = 0.01

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.9,  # factor by which the learning rate will be reduced
    patience=10,  # number of epochs with no improvement after which learning rate will be reduced
    min_lr=0.00001,  # lower bound on the learning rate
    verbose=1
)
lr_callback = tf.keras.callbacks.LearningRateScheduler(reduce_lr)

class PrintLR(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.learning_rates = []
        
    def on_epoch_begin(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        elif hasattr(lr, 'eval'):
            lr = lr.eval(session=tf.compat.v1.Session())
        print(f'Epoch {epoch+1}: Learning rate is {lr}.')
    
    def on_epoch_end(self, epoch, logs=None):
        # Retrieve the current learning rate from the optimizer
        current_lr = tf.keras.backend.get_value(self.model.optimizer.lr)
        # Append the current learning rate to the list
        self.learning_rates.append(current_lr)

lr_tracker = PrintLR()
callbacks = [lr_tracker, early_stopping, reduce_lr]


# Initialize the optimizer with the learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compiling the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Pass the callback to the fit method
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=1000,
    batch_size=16,
    callbacks=callbacks  # include it here
)
# Out:
# Epoch 1: Learning rate is 0.009999999776482582.
# Epoch 1/1000
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8003 - accuracy: 0.5643 - val_loss: 0.7106 - val_accuracy: 0.5755
# Epoch 2: Learning rate is 0.009999999776482582.
# Epoch 2/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.4954 - accuracy: 0.7762 - val_loss: 0.6477 - val_accuracy: 0.7358
# Epoch 3: Learning rate is 0.009999999776482582.
# Epoch 3/1000
# 27/27 [==============================] - 0s 924us/step - loss: 0.4636 - accuracy: 0.8167 - val_loss: 0.6027 - val_accuracy: 0.7264
# Epoch 4: Learning rate is 0.009999999776482582.
# Epoch 4/1000
# 27/27 [==============================] - 0s 979us/step - loss: 0.3792 - accuracy: 0.8143 - val_loss: 0.4985 - val_accuracy: 0.7830
# Epoch 5: Learning rate is 0.009999999776482582.
# Epoch 5/1000
# 27/27 [==============================] - 0s 887us/step - loss: 0.3203 - accuracy: 0.8595 - val_loss: 0.5049 - val_accuracy: 0.7830
# Epoch 6: Learning rate is 0.009999999776482582.
# Epoch 6/1000
# 27/27 [==============================] - 0s 1ms/step - loss: 0.3250 - accuracy: 0.8524 - val_loss: 0.5175 - val_accuracy: 0.7925
# Epoch 7: Learning rate is 0.009999999776482582.
# Epoch 7/1000
# 27/27 [==============================] - 0s 924us/step - loss: 0.3137 - accuracy: 0.8619 - val_loss: 0.4871 - val_accuracy: 0.7830
# Epoch 8: Learning rate is 0.009999999776482582.
# Epoch 8/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.3037 - accuracy: 0.8690 - val_loss: 0.4936 - val_accuracy: 0.7830
# Epoch 9: Learning rate is 0.009999999776482582.
# Epoch 9/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.2671 - accuracy: 0.8881 - val_loss: 0.4241 - val_accuracy: 0.7925
# Epoch 10: Learning rate is 0.009999999776482582.
# Epoch 10/1000
# 27/27 [==============================] - 0s 887us/step - loss: 0.2463 - accuracy: 0.8833 - val_loss: 0.5133 - val_accuracy: 0.7736
# Epoch 11: Learning rate is 0.009999999776482582.
# Epoch 11/1000
# 27/27 [==============================] - 0s 905us/step - loss: 0.2689 - accuracy: 0.8690 - val_loss: 0.5095 - val_accuracy: 0.7925
# Epoch 12: Learning rate is 0.009999999776482582.
# Epoch 12/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.2307 - accuracy: 0.9024 - val_loss: 0.5011 - val_accuracy: 0.8019
# Epoch 13: Learning rate is 0.009999999776482582.
# Epoch 13/1000
# 27/27 [==============================] - 0s 924us/step - loss: 0.2126 - accuracy: 0.9048 - val_loss: 0.6092 - val_accuracy: 0.8113
# Epoch 14: Learning rate is 0.009999999776482582.
# Epoch 14/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.2187 - accuracy: 0.9119 - val_loss: 0.4613 - val_accuracy: 0.8019
# Epoch 15: Learning rate is 0.009999999776482582.
# Epoch 15/1000
# 27/27 [==============================] - 0s 905us/step - loss: 0.2237 - accuracy: 0.9024 - val_loss: 0.5100 - val_accuracy: 0.7830
# Epoch 16: Learning rate is 0.009999999776482582.
# Epoch 16/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.2016 - accuracy: 0.9071 - val_loss: 0.5172 - val_accuracy: 0.8208
# Epoch 17: Learning rate is 0.009999999776482582.
# Epoch 17/1000
# 27/27 [==============================] - 0s 886us/step - loss: 0.2259 - accuracy: 0.8976 - val_loss: 0.4758 - val_accuracy: 0.8019
# Epoch 18: Learning rate is 0.009999999776482582.
# Epoch 18/1000
# 27/27 [==============================] - 0s 925us/step - loss: 0.2109 - accuracy: 0.9071 - val_loss: 0.6598 - val_accuracy: 0.8302
# Epoch 19: Learning rate is 0.009999999776482582.
# Epoch 19/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.1362 - accuracy: 0.9375
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.008999999798834325.
# 27/27 [==============================] - 0s 887us/step - loss: 0.2616 - accuracy: 0.8857 - val_loss: 0.4623 - val_accuracy: 0.8208
# Epoch 20: Learning rate is 0.008999999612569809.
# Epoch 20/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0
1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.0320 - accuracy: 0.9857 - val_loss: 0.9489 - val_accuracy: 0.8113
# Epoch 53: Learning rate is 0.006560999434441328.
# Epoch 53/1000
# 27/27 [==============================] - 0s 851us/step - loss: 0.0384 - accuracy: 0.9857 - val_loss: 0.8150 - val_accuracy: 0.8302
# Epoch 54: Learning rate is 0.006560999434441328.
# Epoch 54/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0338 - accuracy: 0.9833 - val_loss: 1.0570 - val_accuracy: 0.7830
# Epoch 55: Learning rate is 0.006560999434441328.
# Epoch 55/1000
# 27/27 [==============================] - 0s 776us/step - loss: 0.0291 - accuracy: 0.9833 - val_loss: 0.9792 - val_accuracy: 0.8113
# Epoch 56: Learning rate is 0.006560999434441328.
# Epoch 56/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0262 - accuracy: 0.9881 - val_loss: 0.8044 - val_accuracy: 0.8208
# Epoch 57: Learning rate is 0.006560999434441328.
# Epoch 57/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0180 - accuracy: 0.9905 - val_loss: 0.9786 - val_accuracy: 0.8019
# Epoch 58: Learning rate is 0.006560999434441328.
# Epoch 58/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0150 - accuracy: 0.9905 - val_loss: 0.9957 - val_accuracy: 0.8019
# Epoch 59: Learning rate is 0.006560999434441328.
# Epoch 59/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0144 - accuracy: 0.9905 - val_loss: 1.0001 - val_accuracy: 0.8019
# Epoch 60: Learning rate is 0.006560999434441328.
# Epoch 60/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.005904899490997195.
# 27/27 [==============================] - 0s 850us/step - loss: 0.0150 - accuracy: 0.9905 - val_loss: 1.0242 - val_accuracy: 0.8019
# Epoch 61: Learning rate is 0.0059048994444310665.
# Epoch 61/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0128 - accuracy: 0.9929 - val_loss: 1.0063 - val_accuracy: 0.8113
# Epoch 62: Learning rate is 0.0059048994444310665.
# Epoch 62/1000
# 27/27 [==============================] - 0s 869us/step - loss: 0.0121 - accuracy: 0.9929 - val_loss: 0.9855 - val_accuracy: 0.8113
# Epoch 63: Learning rate is 0.0059048994444310665.
# Epoch 63/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0287 - accuracy: 0.9833 - val_loss: 1.0293 - val_accuracy: 0.8208
# Epoch 64: Learning rate is 0.0059048994444310665.
# Epoch 64/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.1129 - accuracy: 0.9548 - val_loss: 1.0550 - val_accuracy: 0.7642
# Epoch 65: Learning rate is 0.0059048994444310665.
# Epoch 65/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.1269 - accuracy: 0.9524 - val_loss: 1.0421 - val_accuracy: 0.8113
# Epoch 66: Learning rate is 0.0059048994444310665.
# Epoch 66/1000
# 27/27 [==============================] - 0s 832us/step - loss: 0.0599 - accuracy: 0.9762 - val_loss: 1.0268 - val_accuracy: 0.8113
# Epoch 67: Learning rate is 0.0059048994444310665.
# Epoch 67/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0396 - accuracy: 0.9810 - val_loss: 0.9545 - val_accuracy: 0.8113
# Epoch 68: Learning rate is 0.0059048994444310665.
# Epoch 68/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0277 - accuracy: 0.9905 - val_loss: 0.9866 - val_accuracy: 0.8302
# Epoch 69: Learning rate is 0.0059048994444310665.
# Epoch 69/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0184 - accuracy: 0.9905 - val_loss: 1.0601 - val_accuracy: 0.8208
# Epoch 70: Learning rate is 0.0059048994444310665.
# Epoch 70/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.00531440949998796.
# 27/27 [==============================] - 0s 905us/step - loss: 0.0156 - accuracy: 0.9881 - val_loss: 1.1031 - val_accuracy: 0.8208
# Epoch 71: Learning rate is 0.0053144097328186035.
# Epoch 71/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.0140 - accuracy: 0.9905 - val_loss: 1.1143 - val_accuracy: 0.8019
# Epoch 72: Learning rate is 0.0053144097328186035.
# Epoch 72/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.0130 - accuracy: 0.9905 - val_loss: 1.1107 - val_accuracy: 0.8208
# Epoch 73: Learning rate is 0.0053144097328186035.
# Epoch 73/1000
# 27/27 [==============================] - 0s 961us/step - loss: 0.0118 - accuracy: 0.9905 - val_loss: 1.1455 - val_accuracy: 0.8113
# Epoch 74: Learning rate is 0.0053144097328186035.
# Epoch 74/1000
# 27/27 [==============================] - 0s 869us/step - loss: 0.0114 - accuracy: 0.9929 - val_loss: 1.1661 - val_accuracy: 0.8208
# Epoch 75: Learning rate is 0.0053144097328186035.
# Epoch 75/1000
# 27/27 [==============================] - 0s 923us/step - loss: 0.0111 - accuracy: 0.9929 - val_loss: 1.1910 - val_accuracy: 0.8208
# Epoch 76: Learning rate is 0.0053144097328186035.
# Epoch 76/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0103 - accuracy: 0.9929 - val_loss: 1.2078 - val_accuracy: 0.8208
# Epoch 77: Learning rate is 0.0053144097328186035.
# Epoch 77/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0099 - accuracy: 0.9929 - val_loss: 1.2095 - val_accuracy: 0.8208
# Epoch 78: Learning rate is 0.0053144097328186035.
# Epoch 78/1000
# 27/27 [==============================] - 0s 905us/step - loss: 0.0097 - accuracy: 0.9929 - val_loss: 1.2387 - val_accuracy: 0.8208
# Epoch 79: Learning rate is 0.0053144097328186035.
# Epoch 79/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0093 - accuracy: 0.9929 - val_loss: 1.2564 - val_accuracy: 0.8208
# Epoch 80: Learning rate is 0.0053144097328186035.
# Epoch 80/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.0853 - accuracy: 0.9375
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.004782968759536744.
# 27/27 [==============================] - 0s 813us/step - loss: 0.0093 - accuracy: 0.9952 - val_loss: 1.2233 - val_accuracy: 0.8208
# Epoch 81: Learning rate is 0.004782968666404486.
# Epoch 81/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0089 - accuracy: 0.9976 - val_loss: 1.2987 - val_accuracy: 0.8113
# Epoch 82: Learning rate is 0.004782968666404486.
# Epoch 82/1000
# 27/27 [==============================] - 0s 905us/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 1.3207 - val_accuracy: 0.8208
# Epoch 83: Learning rate is 0.004782968666404486.
# Epoch 83/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 1.3310 - val_accuracy: 0.8113
# Epoch 84: Learning rate is 0.004782968666404486.
# Epoch 84/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 1.3430 - val_accuracy: 0.8208
# Epoch 85: Learning rate is 0.004782968666404486.
# Epoch 85/1000
# 27/27 [==============================] - 0s 776us/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 1.3443 - val_accuracy: 0.8208
# Epoch 86: Learning rate is 0.004782968666404486.
# Epoch 86/1000
# 27/27 [==============================] - 0s 869us/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 1.3458 - val_accuracy: 0.8208
# Epoch 87: Learning rate is 0.004782968666404486.
# Epoch 87/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 1.3538 - val_accuracy: 0.8208
# Epoch 88: Learning rate is 0.004782968666404486.
# Epoch 88/1000
# 27/27 [==============================] - 0s 887us/step - loss: 0.0076 - accuracy: 0.9976 - val_loss:
1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 1.5210 - val_accuracy: 0.8208
# Epoch 108: Learning rate is 0.0038742045871913433.
# Epoch 108/1000
# 27/27 [==============================] - 0s 887us/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 1.5355 - val_accuracy: 0.8208
# Epoch 109: Learning rate is 0.0038742045871913433.
# Epoch 109/1000
# 27/27 [==============================] - 0s 887us/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 1.5482 - val_accuracy: 0.8208
# Epoch 110: Learning rate is 0.0038742045871913433.
# Epoch 110/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.0496 - accuracy: 0.9375
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
# 27/27 [==============================] - 0s 832us/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 1.5257 - val_accuracy: 0.8208
# Epoch 111: Learning rate is 0.0034867841750383377.
# Epoch 111/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 1.5375 - val_accuracy: 0.8208
# Epoch 112: Learning rate is 0.0034867841750383377.
# Epoch 112/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 1.5472 - val_accuracy: 0.8208
# Epoch 113: Learning rate is 0.0034867841750383377.
# Epoch 113/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0058 - accuracy: 0.9976 - val_loss: 1.5586 - val_accuracy: 0.8208
# Epoch 114: Learning rate is 0.0034867841750383377.
# Epoch 114/1000
# 27/27 [==============================] - 0s 832us/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 1.5766 - val_accuracy: 0.8208
# Epoch 115: Learning rate is 0.0034867841750383377.
# Epoch 115/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 1.5875 - val_accuracy: 0.8208
# Epoch 116: Learning rate is 0.0034867841750383377.
# Epoch 116/1000
# 27/27 [==============================] - 0s 813us/step - loss: 0.0057 - accuracy: 0.9976 - val_loss: 1.5545 - val_accuracy: 0.8208
# Epoch 117: Learning rate is 0.0034867841750383377.
# Epoch 117/1000
# 27/27 [==============================] - 0s 776us/step - loss: 0.0059 - accuracy: 0.9976 - val_loss: 1.6163 - val_accuracy: 0.8113
# Epoch 118: Learning rate is 0.0034867841750383377.
# Epoch 118/1000
# 27/27 [==============================] - 0s 832us/step - loss: 0.0053 - accuracy: 0.9976 - val_loss: 1.6703 - val_accuracy: 0.8113
# Epoch 119: Learning rate is 0.0034867841750383377.
# Epoch 119/1000
# 27/27 [==============================] - 0s 850us/step - loss: 0.0049 - accuracy: 0.9976 - val_loss: 1.6717 - val_accuracy: 0.8019
# Epoch 120: Learning rate is 0.0034867841750383377.
# Epoch 120/1000
#  1/27 [>.............................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000Restoring model weights from the end of the best epoch.
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 0.003138105757534504.
# 27/27 [==============================] - 0s 886us/step - loss: 0.0046 - accuracy: 0.9976 - val_loss: 1.6726 - val_accuracy: 0.8113
# Epoch 00120: early stopping

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 5/5 [==============================] - 0s 598us/step - loss: 0.3877 - accuracy: 0.8182
# Test accuracy: 0.8181818127632141
# Test loss: 0.38767898082733154

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
confusion_matrix(y_test, y_pred)
# Out:
# array([[43,  1,  0],
#        [ 2, 35, 10],
#        [ 0, 11, 30]], dtype=int64)

# %%
# Plotting the training and validation loss
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# Plotting
# plt.figure(figsize=(8, 8))
plt.plot(lr_tracker.learning_rates)
plt.title("Learning Rate over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.grid(True)
