# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# List all physical devices
physical_devices = tf.config.list_physical_devices()
print("Physical devices:", physical_devices)

# Check for GPU specifically
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU is available.")
else:
    print("GPU is NOT available.")
# Out:
# Physical devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# GPU is NOT available.

# %%
# Load your dataset
dataset = pd.read_csv('Dataset.csv')  # Replace with your dataset path
dataset.iloc[:, -1] = dataset.iloc[:, -1] - 1
X = dataset.iloc[:, :-1]  # Features
y = dataset.iloc[:, -1]   # Target

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert labels to categorical
y_categorical = to_categorical(y)

# Shuffle the data
X_scaled, y_categorical = shuffle(X_scaled, y_categorical, random_state=42)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42)

# Number of unique classes in the target variable
num_classes = y_train.shape[1]


# Building the DNN model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],), name='dense_0'),
    Dense(64, activation='relu', name='dense_1'),
    Dense(32, activation='relu', name='dense_2'),
    Dense(num_classes, activation='softmax')  # Output layer
])

# %%
# Define the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,  # minimium amount of change to count as an improvement
    patience=100,  # how many epochs to wait before stopping
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# Set the learning rate
learning_rate = 0.01

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.9,  # factor by which the learning rate will be reduced
    patience=5,  # number of epochs with no improvement after which learning rate will be reduced
    min_lr=0.00001,  # lower bound on the learning rate
    verbose=1
)
lr_callback = tf.keras.callbacks.LearningRateScheduler(reduce_lr)

class PrintLR(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.learning_rates = []
        
    def on_epoch_begin(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        elif hasattr(lr, 'eval'):
            lr = lr.eval(session=tf.compat.v1.Session())
        print(f'Epoch {epoch+1}: Learning rate is {lr}.')
    
    def on_epoch_end(self, epoch, logs=None):
        # Retrieve the current learning rate from the optimizer
        current_lr = tf.keras.backend.get_value(self.model.optimizer.lr)
        # Append the current learning rate to the list
        self.learning_rates.append(current_lr)

lr_tracker = PrintLR()
callbacks = [lr_tracker, early_stopping, reduce_lr]


# Initialize the optimizer with the learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compiling the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Pass the callback to the fit method
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=1000,
    batch_size=64,
    callbacks=callbacks  # include it here
)
# Out:
# Epoch 1: Learning rate is 0.009999999776482582.
# Epoch 1/1000
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5754 - accuracy: 0.6907 - val_loss: 0.4053 - val_accuracy: 0.7789
# Epoch 2: Learning rate is 0.009999999776482582.
# Epoch 2/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4118 - accuracy: 0.7828 - val_loss: 0.4593 - val_accuracy: 0.7638
# Epoch 3: Learning rate is 0.009999999776482582.
# Epoch 3/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8359 - val_loss: 0.3547 - val_accuracy: 0.8090
# Epoch 4: Learning rate is 0.009999999776482582.
# Epoch 4/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2962 - accuracy: 0.8687 - val_loss: 0.4361 - val_accuracy: 0.8141
# Epoch 5: Learning rate is 0.009999999776482582.
# Epoch 5/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8371 - val_loss: 0.3595 - val_accuracy: 0.8442
# Epoch 6: Learning rate is 0.009999999776482582.
# Epoch 6/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.8750 - val_loss: 0.3548 - val_accuracy: 0.8392
# Epoch 7: Learning rate is 0.009999999776482582.
# Epoch 7/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2531 - accuracy: 0.8813 - val_loss: 0.5065 - val_accuracy: 0.7739
# Epoch 8: Learning rate is 0.009999999776482582.
# Epoch 8/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.4557 - accuracy: 0.7969
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.008999999798834325.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2750 - accuracy: 0.8725 - val_loss: 0.3957 - val_accuracy: 0.8392
# Epoch 9: Learning rate is 0.008999999612569809.
# Epoch 9/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2339 - accuracy: 0.8763 - val_loss: 0.3520 - val_accuracy: 0.8693
# Epoch 10: Learning rate is 0.008999999612569809.
# Epoch 10/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 0.8977 - val_loss: 0.4425 - val_accuracy: 0.8090
# Epoch 11: Learning rate is 0.008999999612569809.
# Epoch 11/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9192 - val_loss: 0.3695 - val_accuracy: 0.8693
# Epoch 12: Learning rate is 0.008999999612569809.
# Epoch 12/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1903 - accuracy: 0.9066 - val_loss: 0.4765 - val_accuracy: 0.8191
# Epoch 13: Learning rate is 0.008999999612569809.
# Epoch 13/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9040 - val_loss: 0.3748 - val_accuracy: 0.8693
# Epoch 14: Learning rate is 0.008999999612569809.
# Epoch 14/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2015 - accuracy: 0.9219
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.008099999651312828.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.9167 - val_loss: 0.4396 - val_accuracy: 0.8543
# Epoch 15: Learning rate is 0.008099999278783798.
# Epoch 15/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1998 - accuracy: 0.9078 - val_loss: 0.3691 - val_accuracy: 0.8693
# Epoch 16: Learning rate is 0.008099999278783798.
# Epoch 16/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1633 - accuracy: 0.9293 - val_loss: 0.3897 - val_accuracy: 0.8593
# Epoch 17: Learning rate is 0.008099999278783798.
# Epoch 17/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1595 - accuracy: 0.9343 - val_loss: 0.4625 - val_accuracy: 0.8543
# Epoch 18: Learning rate is 0.008099999278783798.
# Epoch 18/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9116 - val_loss: 0.3893 - val_accuracy: 0.8593
# Epoch 19: Learning rate is 0.008099999278783798.
# Epoch 19/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2265 - accuracy: 0.9062
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.007289999350905419.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1462 - accuracy: 0.9470 - val_loss: 0.4556 - val_accuracy: 0.8593
# Epoch 20: Learning rate is 0.0072899991646409035.
# Epoch 20/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9167 - val_loss: 0.3626 - val_accuracy: 0.8643
# Epoch 21: Learning rate is 0.0072899991646409035.
# Epoch 21/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1452 - accuracy: 0.9470 - val_loss: 0.4030 - val_accuracy: 0.8693
# Epoch 22: Learning rate is 0.0072899991646409035.
# Epoch 22/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1275 - accuracy: 0.9482 - val_loss: 0.4750 - val_accuracy: 0.8693
# Epoch 23: Learning rate is 0.0072899991646409035.
# Epoch 23/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1221 - accuracy: 0.9545 - val_loss: 0.4611 - val_accuracy: 0.8442
# Epoch 24: Learning rate is 0.0072899991646409035.
# Epoch 24/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2451 - accuracy: 0.9062
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.006560999248176813.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.9419 - val_loss: 0.4959 - val_accuracy: 0.8643
# Epoch 25: Learning rate is 0.006560999434441328.
# Epoch 25/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1174 - accuracy: 0.9545 - val_loss: 0.4846 - val_accuracy: 0.8693
# Epoch 26: Learning rate is 0.006560999434441328.
# Epoch 26/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1165 - accuracy: 0.9583 - val_loss: 0.4690 - val_accuracy: 0.8693
# Epoch 27: Learning rate is 0.006560999434441328.
# Epoch 27/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9621 - val_loss: 0.5061 - val_accuracy: 0.8744
# Epoch 28: Learning rate is 0.006560999434441328.
# Epoch 28/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9621 - val_loss: 0.4898 - val_accuracy: 0.8593
# Epoch 29: Learning rate is 0.006560999434441328.
# Epoch 29/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1139 - accuracy: 0.9688
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.005904899490997195.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9571 - val_loss: 0.5052 - val_accuracy: 0.8693
# Epoch 30: Learning rate is 0.0059048994444310665.
# Epoch 30/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9621 - val_loss: 0.5171 - val_accuracy: 0.8643
# Epoch 31: Learning rate is 0.0059048994444310665.
# Epoch 31/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0938 - accuracy: 0.9659 - val_loss: 0.5349 - val_accuracy: 0.8744
# Epoch 32: Learning rate is 0.0059048994444310665.
# Epoch 32/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1081 - accuracy: 0.9545 - val_loss: 0.4849 - val_accuracy: 0.8794
# Epoch 33: Learning rate is 0.0059048994444310665.
# Epoch 33/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.9672 - val_loss: 0.4949 - val_accuracy: 0.8844
# Epoch 34: Learning rate is 0.0059048994444310665.
# Epoch 34/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1110 - accuracy: 0.9688
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00531440949998796.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9621 - val_loss: 0.5235 - val_accuracy: 0.8844
# Epoch 35: Learning rate is 0.0053144097328186035.
# Epoch 35/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.9583 - val_loss: 0.5162 - val_accuracy: 0.8392
# Epoch 36: Learning rate is 0.0053144097328186035.
# Epoch 36/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9697 - val_loss: 0.4833 - val_accuracy: 0.8643
# Epoch 37: Learning rate is 0.0053144097328186035.
# Epoch 37/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0809 - accuracy: 0.9710 - val_loss: 0.5087 - val_accuracy: 0.8643
# Epoch 38: Learning rate is 0.0053144097328186035.
# Epoch 38/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9583 - val_loss: 0.5005 - val_accuracy: 0.8744
# Epoch 39: Learning rate is 0.0053144097328186035.
# Epoch 39/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0595 - accuracy: 0.9688
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.004782968759536744.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9773 - val_loss: 0.5079 - val_accuracy: 0.8844
# Epoch 40: Learning rate is 0.004782968666404486.
# Epoch 40/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 0.9747 - val_loss: 0.5164 - val_accuracy: 0.8794
# Epoch 41: Learning rate is 0.004782968666404486.
# Epoch 41/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9508 - val_loss: 0.5475 - val_accuracy: 0.8794
# Epoch 42: Learning rate is 0.004782968666404486.
# Epoch 42/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1033 - accuracy: 0.9646 - val_loss: 0.5147 - val_accuracy: 0.8693
# Epoch 43: Learning rate is 0.004782968666404486.
# Epoch 43/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.9735 - val_loss: 0.5112 - val_accuracy: 0.8844
# Epoch 44: Learning rate is 0.004782968666404486.
# Epoch 44/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0586 - accuracy: 0.9688
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0043046717997640375.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9646 - val_loss: 0.5534 - val_accuracy: 0.8945
# Epoch 45: Learning rate is 0.004304671660065651.
# Epoch 45/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9646 - val_loss: 0.6498 - val_accuracy: 0.8844
# Epoch 46: Learning rate is 0.004304671660065651.
# Epoch 46/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9634 - val_loss: 0.5438 - val_accuracy: 0.8945
# Epoch 47: Learning rate is 0.004304671660065651.
# Epoch 47/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9798 - val_loss: 0.6231 - val_accuracy: 0.8794
# Epoch 48: Learning rate is 0.004304671660065651.
# Epoch 48/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0545 - accuracy: 0.9760 - val_loss: 0.5696 - val_accuracy: 0.8844
# Epoch 49: Learning rate is 0.004304671660065651.
# Epoch 49/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0695 - accuracy: 0.9531
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0038742044940590858.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9811 - val_loss: 0.6247 - val_accuracy: 0.8894
# Epoch 50: Learning rate is 0.0038742045871913433.
# Epoch 50/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0565 - accuracy: 0.9798 - val_loss: 0.5839 - val_accuracy: 0.9095
# Epoch 51: Learning rate is 0.0038742045871913433.
# Epoch 51/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9785 - val_loss: 0.5920 - val_accuracy: 0.8945
# Epoch 52: Learning rate is 0.0038742045871913433.
# Epoch 52/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0434 - accuracy: 0.9798 - val_loss: 0.5770 - val_accuracy: 0.8894
# Epoch 53: Learning rate is 0.0038742045871913433.
# Epoch 53/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 0.9823 - val_loss: 0.5996 - val_accuracy: 0.9045
# Epoch 54: Learning rate is 0.0038742045871913433.
# Epoch 54/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0164 - accuracy: 1.0000
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9823 - val_loss: 0.5722 - val_accuracy: 0.8844
# Epoch 55: Learning rate is 0.0034867841750383377.
# Epoch 55/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9773 - val_loss: 0.6764 - val_accuracy: 0.8392
# Epoch 56: Learning rate is 0.0034867841750383377.
# Epoch 56/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 0.9722 - val_loss: 0.6130 - val_accuracy: 0.8844
# Epoch 57: Learning rate is 0.0034867841750383377.
# Epoch 57/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0564 - accuracy: 0.9760 - val_loss: 0.5904 - val_accuracy: 0.8995
# Epoch 58: Learning rate is 0.0034867841750383377.
# Epoch 58/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9798 - val_loss: 0.6113 - val_accuracy: 0.8945
# Epoch 59: Learning rate is 0.0034867841750383377.
# Epoch 59/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0409 - accuracy: 0.9844
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.003138105757534504.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0453 - accuracy: 0.9798 - val_loss: 0.5240 - val_accuracy: 0.9045
# Epoch 60: Learning rate is 0.0031381058506667614.
# Epoch 60/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0487 - accuracy: 0.9798 - val_loss: 0.5439 - val_accuracy: 0.8794
# Epoch 61: Learning rate is 0.0031381058506667614.
# Epoch 61/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0497 - accuracy: 0.9848 - val_loss: 0.6381 - val_accuracy: 0.8744
# Epoch 62: Learning rate is 0.0031381058506667614.
# Epoch 62/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0510 - accuracy: 0.9785 - val_loss: 0.5743 - val_accuracy: 0.8945
# Epoch 63: Learning rate is 0.0031381058506667614.
# Epoch 63/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0579 - accuracy: 0.9823 - val_loss: 0.8984 - val_accuracy: 0.8995
# Epoch 64: Learning rate is 0.0031381058506667614.
# Epoch 64/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0523 - accuracy: 0.9844
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0028242952656000854.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1640 - accuracy: 0.9684 - val_loss: 0.9711 - val_accuracy: 0.8744
# Epoch 65: Learning rate is 0.002824295312166214.
# Epoch 65/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9747 - val_loss: 0.5789 - val_accuracy: 0.8995
# Epoch 66: Learning rate is 0.002824295312166214.
# Epoch 66/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0550 - accuracy: 0.9861 - val_loss: 0.5846 - val_accuracy: 0.8894
# Epoch 67: Learning rate is 0.002824295312166214.
# Epoch 67/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9848 - val_loss: 0.4716 - val_accuracy: 0.8794
# Epoch 68: Learning rate is 0.002824295312166214.
# Epoch 68/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9912 - val_loss: 0.4855 - val_accuracy: 0.9146
# Epoch 69: Learning rate is 0.002824295312166214.
# Epoch 69/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0431 - accuracy: 0.9844
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0025418657809495927.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9886 - val_loss: 0.5208 - val_accuracy: 0.8945
# Epoch 70: Learning rate is 0.002541865687817335.
# Epoch 70/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9886 - val_loss: 0.5491 - val_accuracy: 0.9045
# Epoch 71: Learning rate is 0.002541865687817335.
# Epoch 71/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9899 - val_loss: 0.5415 - val_accuracy: 0.9095
# Epoch 72: Learning rate is 0.002541865687817335.
# Epoch 72/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.5689 - val_accuracy: 0.9095
# Epoch 73: Learning rate is 0.002541865687817335.
# Epoch 73/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9836 - val_loss: 0.5446 - val_accuracy: 0.9045
# Epoch 74: Learning rate is 0.002541865687817335.
# Epoch 74/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0185 - accuracy: 0.9844
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0022876791190356016.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9848 - val_loss: 0.5115 - val_accuracy: 0.9045
# Epoch 75: Learning rate is 0.0022876791190356016.
# Epoch 75/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.9899 - val_loss: 0.5426 - val_accuracy: 0.8945
# Epoch 76: Learning rate is 0.0022876791190356016.
# Epoch 76/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 0.6036 - val_accuracy: 0.9146
# Epoch 77: Learning rate is 0.0022876791190356016.
# Epoch 77/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 0.9912 - val_loss: 0.5712 - val_accuracy: 0.9045
# Epoch 78: Learning rate is 0.0022876791190356016.
# Epoch 78/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 0.9912 - val_loss: 0.5830 - val_accuracy: 0.8894
# Epoch 79: Learning rate is 0.0022876791190356016.
# Epoch 79/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0592 - accuracy: 0.9688
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.0020589112071320416.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9848 - val_loss: 0.6223 - val_accuracy: 0.9146
# Epoch 80: Learning rate is 0.0020589111372828484.
# Epoch 80/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9912 - val_loss: 0.5983 - val_accuracy: 0.9146
# Epoch 81: Learning rate is 0.0020589111372828484.
# Epoch 81/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0242 - accuracy: 0.9937 - val_loss: 0.5616 - val_accuracy: 0.8945
# Epoch 82: Learning rate is 0.0020589111372828484.
# Epoch 82/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 0.6102 - val_accuracy: 0.9146
# Epoch 83: Learning rate is 0.0020589111372828484.
# Epoch 83/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 0.9949 - val_loss: 0.5891 - val_accuracy: 0.9045
# Epoch 84: Learning rate is 0.0020589111372828484.
# Epoch 84/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0140 - accuracy: 1.0000
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.0018530200235545636.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9962 - val_loss: 0.6289 - val_accuracy: 0.9146
# Epoch 85: Learning rate is 0.0018530200468376279.
# Epoch 85/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.6200 - val_accuracy: 0.9146
# Epoch 86: Learning rate is 0.0018530200468376279.
# Epoch 86/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0174 - accuracy: 0.9962 - val_loss: 0.6092 - val_accuracy: 0.9146
# Epoch 87: Learning rate is 0.0018530200468376279.
# Epoch 87/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9962 - val_loss: 0.6241 - val_accuracy: 0.9196
# Epoch 88: Learning rate is 0.0018530200468376279.
# Epoch 88/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0187 - accuracy: 0.9962 - val_loss: 0.6282 - val_accuracy: 0.9196
# Epoch 89: Learning rate is 0.0018530200468376279.
# Epoch 89/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.0016677180421538651.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0190 - accuracy: 0.9924 - val_loss: 0.6049 - val_accuracy: 0.9045
# Epoch 90: Learning rate is 0.0016677180537953973.
# Epoch 90/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0197 - accuracy: 0.9949 - val_loss: 0.6333 - val_accuracy: 0.9095
# Epoch 91: Learning rate is 0.0016677180537953973.
# Epoch 91/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 0.9962 - val_loss: 0.6344 - val_accuracy: 0.9146
# Epoch 92: Learning rate is 0.0016677180537953973.
# Epoch 92/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9962 - val_loss: 0.6707 - val_accuracy: 0.9196
# Epoch 93: Learning rate is 0.0016677180537953973.
# Epoch 93/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0147 - accuracy: 0.9975 - val_loss: 0.6511 - val_accuracy: 0.9146
# Epoch 94: Learning rate is 0.0016677180537953973.
# Epoch 94/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.0015009462484158575.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.6508 - val_accuracy: 0.9146
# Epoch 95: Learning rate is 0.0015009462367743254.
# Epoch 95/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.6336 - val_accuracy: 0.9146
# Epoch 96: Learning rate is 0.0015009462367743254.
# Epoch 96/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9975 - val_loss: 0.6513 - val_accuracy: 0.9146
# Epoch 97: Learning rate is 0.0015009462367743254.
# Epoch 97/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.6571 - val_accuracy: 0.9146
# Epoch 98: Learning rate is 0.0015009462367743254.
# Epoch 98/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.9975 - val_loss: 0.6680 - val_accuracy: 0.9146
# Epoch 99: Learning rate is 0.0015009462367743254.
# Epoch 99/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.0013508516130968928.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9912 - val_loss: 0.6550 - val_accuracy: 0.9045
# Epoch 100: Learning rate is 0.0013508516130968928.
# Epoch 100/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.6601 - val_accuracy: 0.9146
# Epoch 101: Learning rate is 0.0013508516130968928.
# Epoch 101/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.6643 - val_accuracy: 0.9146
# Epoch 102: Learning rate is 0.0013508516130968928.
# Epoch 102/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.6614 - val_accuracy: 0.9146
# Epoch 103: Learning rate is 0.0013508516130968928.
# Epoch 103/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.6711 - val_accuracy: 0.9146
# Epoch 104: Learning rate is 0.0013508516130968928.
# Epoch 104/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0307 - accuracy: 0.9844
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 0.0012157664517872036.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.6722 - val_accuracy: 0.9146
# Epoch 105: Learning rate is 0.001215766416862607.
# Epoch 105/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 0.9975 - val_loss: 0.6736 - val_accuracy: 0.9045
# Epoch 106: Learning rate is 0.001215766416862607.
# Epoch 106/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 0.9987 - val_loss: 0.6808 - val_accuracy: 0.9146
# Epoch 107: Learning rate is 0.001215766416862607.
# Epoch 107/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 0.9987 - val_loss: 0.6867 - val_accuracy: 0.9045
# Epoch 108: Learning rate is 0.001215766416862607.
# Epoch 108/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.6965 - val_accuracy: 0.9146
# Epoch 109: Learning rate is 0.001215766416862607.
# Epoch 109/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000Restoring model weights from the end of the best epoch.
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 0.0010941897751763463.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 0.9975 - val_loss: 0.6891 - val_accuracy: 0.9095
# Epoch 00109: early stopping

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 8/8 [==============================] - 0s 499us/step - loss: 0.2926 - accuracy: 0.8992
# Test accuracy: 0.899193525314331
# Test loss: 0.29257163405418396

# %%
# Plotting the training and validation loss
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# Plotting
# plt.figure(figsize=(8, 8))
plt.plot(lr_tracker.learning_rates)
plt.title("Learning Rate over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.grid(True)

# %%
# Save the model
tf.keras.models.save_model(model, 'exo_model')
# Out:
# INFO:tensorflow:Assets written to: exo_model\assets

# %%
from tensorflow.keras.models import Model

model = tf.keras.models.load_model('exo_model')
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0 (Dense)              (None, 128)               8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_62 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 18,627
# Trainable params: 18,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Assume 'original_model' is your pre-trained model
model_without_softmax = Model(inputs=model.input, 
                              outputs=model.get_layer("dense_2").output)
model_without_softmax.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0_input (InputLayer)   [(None, 63)]              0
# _________________________________________________________________
# dense_0 (Dense)              (None, 128)               8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# =================================================================
# Total params: 18,528
# Trainable params: 18,528
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the model
tf.keras.models.save_model(model_without_softmax, 'exo_model_without_softmax')
# Out:
# WARNING:tensorflow:From C:\Users\shinm\miniconda3\envs\tf23\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\shinm\miniconda3\envs\tf23\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: exo_model_without_softmax\assets

# %%
loaded_model = tf.keras.models.load_model('exo_model_without_softmax')
loaded_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0_input (InputLayer)   [(None, 63)]              0
# _________________________________________________________________
# dense_0 (Dense)              (None, 128)               8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# =================================================================
# Total params: 18,528
# Trainable params: 18,528
# Non-trainable params: 0
# _________________________________________________________________
