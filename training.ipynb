# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# List all physical devices
physical_devices = tf.config.list_physical_devices()
print("Physical devices:", physical_devices)

# Check for GPU specifically
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU is available.")
else:
    print("GPU is NOT available.")
# Out:
# Physical devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# GPU is NOT available.

# %%
# Load your dataset
dataset = pd.read_csv('Dataset.csv')  # Replace with your dataset path
dataset.iloc[:, -1] = dataset.iloc[:, -1] - 1
X = dataset.iloc[:, :-1]  # Features
y = dataset.iloc[:, -1]   # Target

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert labels to categorical
y_categorical = to_categorical(y)

# Shuffle the data
X_scaled, y_categorical = shuffle(X_scaled, y_categorical, random_state=42)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42)

# Number of unique classes in the target variable
num_classes = y_train.shape[1]


# Building the DNN model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],), name='dense_0'),
    Dense(64, activation='relu', name='dense_1'),
    Dense(3, activation='relu', name='dense_2'),
    # Dense(3, activation='relu', name='dense_3'),
    Dense(num_classes, activation='softmax')  # Output layer
])

# %%
# Define the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,  # minimium amount of change to count as an improvement
    patience=100,  # how many epochs to wait before stopping
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# Set the learning rate
learning_rate = 0.01

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.9,  # factor by which the learning rate will be reduced
    patience=5,  # number of epochs with no improvement after which learning rate will be reduced
    min_lr=0.00001,  # lower bound on the learning rate
    verbose=1
)
lr_callback = tf.keras.callbacks.LearningRateScheduler(reduce_lr)

class PrintLR(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.learning_rates = []
        
    def on_epoch_begin(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        elif hasattr(lr, 'eval'):
            lr = lr.eval(session=tf.compat.v1.Session())
        print(f'Epoch {epoch+1}: Learning rate is {lr}.')
    
    def on_epoch_end(self, epoch, logs=None):
        # Retrieve the current learning rate from the optimizer
        current_lr = tf.keras.backend.get_value(self.model.optimizer.lr)
        # Append the current learning rate to the list
        self.learning_rates.append(current_lr)

lr_tracker = PrintLR()
callbacks = [lr_tracker, early_stopping, reduce_lr]


# Initialize the optimizer with the learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compiling the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Pass the callback to the fit method
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=1000,
    batch_size=64,
    callbacks=callbacks  # include it here
)
# Out:
# Epoch 1: Learning rate is 0.009999999776482582.
# Epoch 1/1000
# 13/13 [==============================] - 0s 27ms/step - loss: 0.7545 - accuracy: 0.6566 - val_loss: 0.6289 - val_accuracy: 0.7739
# Epoch 2: Learning rate is 0.009999999776482582.
# Epoch 2/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6157 - accuracy: 0.7879 - val_loss: 0.6146 - val_accuracy: 0.7739
# Epoch 3: Learning rate is 0.009999999776482582.
# Epoch 3/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.8207 - val_loss: 0.5294 - val_accuracy: 0.8492
# Epoch 4: Learning rate is 0.009999999776482582.
# Epoch 4/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.8106 - val_loss: 0.5126 - val_accuracy: 0.8090
# Epoch 5: Learning rate is 0.009999999776482582.
# Epoch 5/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4842 - accuracy: 0.8194 - val_loss: 0.4942 - val_accuracy: 0.8090
# Epoch 6: Learning rate is 0.009999999776482582.
# Epoch 6/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8409 - val_loss: 0.4705 - val_accuracy: 0.8040
# Epoch 7: Learning rate is 0.009999999776482582.
# Epoch 7/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8598 - val_loss: 0.4238 - val_accuracy: 0.8543
# Epoch 8: Learning rate is 0.009999999776482582.
# Epoch 8/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3745 - accuracy: 0.8573 - val_loss: 0.4159 - val_accuracy: 0.8291
# Epoch 9: Learning rate is 0.009999999776482582.
# Epoch 9/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8788 - val_loss: 0.4133 - val_accuracy: 0.8492
# Epoch 10: Learning rate is 0.009999999776482582.
# Epoch 10/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8586 - val_loss: 0.4126 - val_accuracy: 0.8492
# Epoch 11: Learning rate is 0.009999999776482582.
# Epoch 11/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3064 - accuracy: 0.8927 - val_loss: 0.3548 - val_accuracy: 0.8693
# Epoch 12: Learning rate is 0.009999999776482582.
# Epoch 12/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.8902 - val_loss: 0.3812 - val_accuracy: 0.8241
# Epoch 13: Learning rate is 0.009999999776482582.
# Epoch 13/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2938 - accuracy: 0.8838 - val_loss: 0.3675 - val_accuracy: 0.8241
# Epoch 14: Learning rate is 0.009999999776482582.
# Epoch 14/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2699 - accuracy: 0.9040 - val_loss: 0.3583 - val_accuracy: 0.8442
# Epoch 15: Learning rate is 0.009999999776482582.
# Epoch 15/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2553 - accuracy: 0.9028 - val_loss: 0.3411 - val_accuracy: 0.8693
# Epoch 16: Learning rate is 0.009999999776482582.
# Epoch 16/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2449 - accuracy: 0.9091 - val_loss: 0.3411 - val_accuracy: 0.8744
# Epoch 17: Learning rate is 0.009999999776482582.
# Epoch 17/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2411 - accuracy: 0.9167 - val_loss: 0.4017 - val_accuracy: 0.8593
# Epoch 18: Learning rate is 0.009999999776482582.
# Epoch 18/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2521 - accuracy: 0.8977 - val_loss: 0.3532 - val_accuracy: 0.8392
# Epoch 19: Learning rate is 0.009999999776482582.
# Epoch 19/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2293 - accuracy: 0.9078 - val_loss: 0.3362 - val_accuracy: 0.8693
# Epoch 20: Learning rate is 0.009999999776482582.
# Epoch 20/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2245 - accuracy: 0.9242 - val_loss: 0.3556 - val_accuracy: 0.8643
# Epoch 21: Learning rate is 0.009999999776482582.
# Epoch 21/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9293 - val_loss: 0.3305 - val_accuracy: 0.8693
# Epoch 22: Learning rate is 0.009999999776482582.
# Epoch 22/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2047 - accuracy: 0.9343 - val_loss: 0.4122 - val_accuracy: 0.8442
# Epoch 23: Learning rate is 0.009999999776482582.
# Epoch 23/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 0.9457 - val_loss: 0.3558 - val_accuracy: 0.8894
# Epoch 24: Learning rate is 0.009999999776482582.
# Epoch 24/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1912 - accuracy: 0.9306 - val_loss: 0.3237 - val_accuracy: 0.8744
# Epoch 25: Learning rate is 0.009999999776482582.
# Epoch 25/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1770 - accuracy: 0.9369 - val_loss: 0.3429 - val_accuracy: 0.8643
# Epoch 26: Learning rate is 0.009999999776482582.
# Epoch 26/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1726 - accuracy: 0.9394 - val_loss: 0.4141 - val_accuracy: 0.8492
# Epoch 27: Learning rate is 0.009999999776482582.
# Epoch 27/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1800 - accuracy: 0.9217 - val_loss: 0.3812 - val_accuracy: 0.8442
# Epoch 28: Learning rate is 0.009999999776482582.
# Epoch 28/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1715 - accuracy: 0.9331 - val_loss: 0.4112 - val_accuracy: 0.8241
# Epoch 29: Learning rate is 0.009999999776482582.
# Epoch 29/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2609 - accuracy: 0.8906
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.008999999798834325.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2139 - accuracy: 0.9066 - val_loss: 0.3352 - val_accuracy: 0.8693
# Epoch 30: Learning rate is 0.008999999612569809.
# Epoch 30/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.9482 - val_loss: 0.3684 - val_accuracy: 0.8643
# Epoch 31: Learning rate is 0.008999999612569809.
# Epoch 31/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1451 - accuracy: 0.9571 - val_loss: 0.3296 - val_accuracy: 0.8995
# Epoch 32: Learning rate is 0.008999999612569809.
# Epoch 32/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1641 - accuracy: 0.9381 - val_loss: 0.3617 - val_accuracy: 0.8744
# Epoch 33: Learning rate is 0.008999999612569809.
# Epoch 33/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1806 - accuracy: 0.9318 - val_loss: 0.4038 - val_accuracy: 0.8693
# Epoch 34: Learning rate is 0.008999999612569809.
# Epoch 34/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.3950 - accuracy: 0.8281
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.008099999651312828.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2088 - accuracy: 0.9205 - val_loss: 0.4482 - val_accuracy: 0.8794
# Epoch 35: Learning rate is 0.008099999278783798.
# Epoch 35/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.9331 - val_loss: 0.2950 - val_accuracy: 0.8794
# Epoch 36: Learning rate is 0.008099999278783798.
# Epoch 36/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.9331 - val_loss: 0.3323 - val_accuracy: 0.8844
# Epoch 37: Learning rate is 0.008099999278783798.
# Epoch 37/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1881 - accuracy: 0.9470 - val_loss: 0.5421 - val_accuracy: 0.8593
# Epoch 38: Learning rate is 0.008099999278783798.
# Epoch 38/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9381 - val_loss: 0.3716 - val_accuracy: 0.8744
# Epoch 39: Learning rate is 0.008099999278783798.
# Epoch 39/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1676 - accuracy: 0.9343 - val_loss: 0.3528 - val_accuracy: 0.8744
# Epoch 40: Learning rate is 0.008099999278783798.
# Epoch 40/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1337 - accuracy: 0.9688
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.007289999350905419.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9495 - val_loss: 0.3369 - val_accuracy: 0.8693
# Epoch 41: Learning rate is 0.0072899991646409035.
# Epoch 41/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1341 - accuracy: 0.9533 - val_loss: 0.3291 - val_accuracy: 0.8844
# Epoch 42: Learning rate is 0.0072899991646409035.
# Epoch 42/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1243 - accuracy: 0.9621 - val_loss: 0.3083 - val_accuracy: 0.8794
# Epoch 43: Learning rate is 0.0072899991646409035.
# Epoch 43/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9646 - val_loss: 0.3061 - val_accuracy: 0.8945
# Epoch 44: Learning rate is 0.0072899991646409035.
# Epoch 44/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1021 - accuracy: 0.9710 - val_loss: 0.3177 - val_accuracy: 0.8894
# Epoch 45: Learning rate is 0.0072899991646409035.
# Epoch 45/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0734 - accuracy: 0.9844
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.006560999248176813.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 0.9533 - val_loss: 0.3249 - val_accuracy: 0.8844
# Epoch 46: Learning rate is 0.006560999434441328.
# Epoch 46/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0992 - accuracy: 0.9710 - val_loss: 0.3398 - val_accuracy: 0.8844
# Epoch 47: Learning rate is 0.006560999434441328.
# Epoch 47/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9773 - val_loss: 0.3577 - val_accuracy: 0.8844
# Epoch 48: Learning rate is 0.006560999434441328.
# Epoch 48/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1030 - accuracy: 0.9659 - val_loss: 0.3395 - val_accuracy: 0.8894
# Epoch 49: Learning rate is 0.006560999434441328.
# Epoch 49/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9609 - val_loss: 0.3313 - val_accuracy: 0.8995
# Epoch 50: Learning rate is 0.006560999434441328.
# Epoch 50/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0828 - accuracy: 0.9844
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.005904899490997195.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9722 - val_loss: 0.4156 - val_accuracy: 0.8693
# Epoch 51: Learning rate is 0.0059048994444310665.
# Epoch 51/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9508 - val_loss: 0.3393 - val_accuracy: 0.8844
# Epoch 52: Learning rate is 0.0059048994444310665.
# Epoch 52/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 0.9571 - val_loss: 0.3206 - val_accuracy: 0.8995
# Epoch 53: Learning rate is 0.0059048994444310665.
# Epoch 53/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9785 - val_loss: 0.3250 - val_accuracy: 0.9095
# Epoch 54: Learning rate is 0.0059048994444310665.
# Epoch 54/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9747 - val_loss: 0.3490 - val_accuracy: 0.8844
# Epoch 55: Learning rate is 0.0059048994444310665.
# Epoch 55/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0738 - accuracy: 0.9688
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.00531440949998796.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0956 - accuracy: 0.9684 - val_loss: 0.3329 - val_accuracy: 0.8945
# Epoch 56: Learning rate is 0.0053144097328186035.
# Epoch 56/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0910 - accuracy: 0.9722 - val_loss: 0.3225 - val_accuracy: 0.9045
# Epoch 57: Learning rate is 0.0053144097328186035.
# Epoch 57/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0698 - accuracy: 0.9798 - val_loss: 0.3167 - val_accuracy: 0.8945
# Epoch 58: Learning rate is 0.0053144097328186035.
# Epoch 58/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9811 - val_loss: 0.3096 - val_accuracy: 0.9045
# Epoch 59: Learning rate is 0.0053144097328186035.
# Epoch 59/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 0.9735 - val_loss: 0.3308 - val_accuracy: 0.8844
# Epoch 60: Learning rate is 0.0053144097328186035.
# Epoch 60/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0478 - accuracy: 0.9844
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.004782968759536744.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9710 - val_loss: 0.3637 - val_accuracy: 0.8794
# Epoch 61: Learning rate is 0.004782968666404486.
# Epoch 61/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9646 - val_loss: 0.3986 - val_accuracy: 0.8794
# Epoch 62: Learning rate is 0.004782968666404486.
# Epoch 62/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9710 - val_loss: 0.3569 - val_accuracy: 0.8995
# Epoch 63: Learning rate is 0.004782968666404486.
# Epoch 63/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.9811 - val_loss: 0.3546 - val_accuracy: 0.9045
# Epoch 64: Learning rate is 0.004782968666404486.
# Epoch 64/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0787 - accuracy: 0.9785 - val_loss: 0.3322 - val_accuracy: 0.8945
# Epoch 65: Learning rate is 0.004782968666404486.
# Epoch 65/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0297 - accuracy: 1.0000
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.0043046717997640375.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1037 - accuracy: 0.9596 - val_loss: 0.3544 - val_accuracy: 0.8945
# Epoch 66: Learning rate is 0.004304671660065651.
# Epoch 66/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9710 - val_loss: 0.3503 - val_accuracy: 0.8894
# Epoch 67: Learning rate is 0.004304671660065651.
# Epoch 67/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0811 - accuracy: 0.9785 - val_loss: 0.3498 - val_accuracy: 0.8844
# Epoch 68: Learning rate is 0.004304671660065651.
# Epoch 68/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0698 - accuracy: 0.9798 - val_loss: 0.3210 - val_accuracy: 0.8995
# Epoch 69: Learning rate is 0.004304671660065651.
# Epoch 69/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0606 - accuracy: 0.9861 - val_loss: 0.3464 - val_accuracy: 0.8995
# Epoch 70: Learning rate is 0.004304671660065651.
# Epoch 70/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1281 - accuracy: 0.9375
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0038742044940590858.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0645 - accuracy: 0.9798 - val_loss: 0.3370 - val_accuracy: 0.8894
# Epoch 71: Learning rate is 0.0038742045871913433.
# Epoch 71/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9836 - val_loss: 0.3402 - val_accuracy: 0.9045
# Epoch 72: Learning rate is 0.0038742045871913433.
# Epoch 72/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0621 - accuracy: 0.9823 - val_loss: 0.3382 - val_accuracy: 0.9095
# Epoch 73: Learning rate is 0.0038742045871913433.
# Epoch 73/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 0.9886 - val_loss: 0.3415 - val_accuracy: 0.9095
# Epoch 74: Learning rate is 0.0038742045871913433.
# Epoch 74/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0567 - accuracy: 0.9861 - val_loss: 0.3406 - val_accuracy: 0.8995
# Epoch 75: Learning rate is 0.0038742045871913433.
# Epoch 75/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1555 - accuracy: 0.9531
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0564 - accuracy: 0.9848 - val_loss: 0.3429 - val_accuracy: 0.9095
# Epoch 76: Learning rate is 0.0034867841750383377.
# Epoch 76/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0540 - accuracy: 0.9899 - val_loss: 0.3488 - val_accuracy: 0.9045
# Epoch 77: Learning rate is 0.0034867841750383377.
# Epoch 77/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0495 - accuracy: 0.9912 - val_loss: 0.3456 - val_accuracy: 0.9146
# Epoch 78: Learning rate is 0.0034867841750383377.
# Epoch 78/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 0.9823 - val_loss: 0.3523 - val_accuracy: 0.9045
# Epoch 79: Learning rate is 0.0034867841750383377.
# Epoch 79/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0975 - accuracy: 0.9609 - val_loss: 0.3799 - val_accuracy: 0.8945
# Epoch 80: Learning rate is 0.0034867841750383377.
# Epoch 80/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.003138105757534504.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0874 - accuracy: 0.9684 - val_loss: 0.3519 - val_accuracy: 0.9095
# Epoch 81: Learning rate is 0.0031381058506667614.
# Epoch 81/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0622 - accuracy: 0.9848 - val_loss: 0.3489 - val_accuracy: 0.9095
# Epoch 82: Learning rate is 0.0031381058506667614.
# Epoch 82/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 0.9798 - val_loss: 0.3384 - val_accuracy: 0.9095
# Epoch 83: Learning rate is 0.0031381058506667614.
# Epoch 83/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0691 - accuracy: 0.9798 - val_loss: 0.3395 - val_accuracy: 0.9146
# Epoch 84: Learning rate is 0.0031381058506667614.
# Epoch 84/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0560 - accuracy: 0.9874 - val_loss: 0.3666 - val_accuracy: 0.8945
# Epoch 85: Learning rate is 0.0031381058506667614.
# Epoch 85/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0370 - accuracy: 0.9844
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.0028242952656000854.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0537 - accuracy: 0.9861 - val_loss: 0.3345 - val_accuracy: 0.9045
# Epoch 86: Learning rate is 0.002824295312166214.
# Epoch 86/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0502 - accuracy: 0.9912 - val_loss: 0.3441 - val_accuracy: 0.9045
# Epoch 87: Learning rate is 0.002824295312166214.
# Epoch 87/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0527 - accuracy: 0.9886 - val_loss: 0.3329 - val_accuracy: 0.9095
# Epoch 88: Learning rate is 0.002824295312166214.
# Epoch 88/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 0.9899 - val_loss: 0.3381 - val_accuracy: 0.9095
# Epoch 89: Learning rate is 0.002824295312166214.
# Epoch 89/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 0.9899 - val_loss: 0.3376 - val_accuracy: 0.9045
# Epoch 90: Learning rate is 0.002824295312166214.
# Epoch 90/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0908 - accuracy: 0.9844
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 0.0025418657809495927.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 0.9924 - val_loss: 0.3366 - val_accuracy: 0.9196
# Epoch 91: Learning rate is 0.002541865687817335.
# Epoch 91/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9924 - val_loss: 0.3421 - val_accuracy: 0.9045
# Epoch 92: Learning rate is 0.002541865687817335.
# Epoch 92/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9937 - val_loss: 0.3410 - val_accuracy: 0.9146
# Epoch 93: Learning rate is 0.002541865687817335.
# Epoch 93/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0446 - accuracy: 0.9899 - val_loss: 0.3511 - val_accuracy: 0.9146
# Epoch 94: Learning rate is 0.002541865687817335.
# Epoch 94/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0428 - accuracy: 0.9924 - val_loss: 0.3443 - val_accuracy: 0.9095
# Epoch 95: Learning rate is 0.002541865687817335.
# Epoch 95/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1101 - accuracy: 0.9688
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.0022876791190356016.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9924 - val_loss: 0.3537 - val_accuracy: 0.9095
# Epoch 96: Learning rate is 0.0022876791190356016.
# Epoch 96/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9899 - val_loss: 0.3511 - val_accuracy: 0.9196
# Epoch 97: Learning rate is 0.0022876791190356016.
# Epoch 97/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0447 - accuracy: 0.9899 - val_loss: 0.3576 - val_accuracy: 0.9095
# Epoch 98: Learning rate is 0.0022876791190356016.
# Epoch 98/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9874 - val_loss: 0.3663 - val_accuracy: 0.9045
# Epoch 99: Learning rate is 0.0022876791190356016.
# Epoch 99/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9886 - val_loss: 0.3502 - val_accuracy: 0.9146
# Epoch 100: Learning rate is 0.0022876791190356016.
# Epoch 100/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0323 - accuracy: 1.0000
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 0.0020589112071320416.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0458 - accuracy: 0.9912 - val_loss: 0.3677 - val_accuracy: 0.9146
# Epoch 101: Learning rate is 0.0020589111372828484.
# Epoch 101/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0468 - accuracy: 0.9899 - val_loss: 0.3547 - val_accuracy: 0.9146
# Epoch 102: Learning rate is 0.0020589111372828484.
# Epoch 102/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0444 - accuracy: 0.9912 - val_loss: 0.3628 - val_accuracy: 0.9095
# Epoch 103: Learning rate is 0.0020589111372828484.
# Epoch 103/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0455 - accuracy: 0.9899 - val_loss: 0.3529 - val_accuracy: 0.9196
# Epoch 104: Learning rate is 0.0020589111372828484.
# Epoch 104/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0401 - accuracy: 0.9924 - val_loss: 0.3577 - val_accuracy: 0.9095
# Epoch 105: Learning rate is 0.0020589111372828484.
# Epoch 105/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0175 - accuracy: 1.0000
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 0.0018530200235545636.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9924 - val_loss: 0.3568 - val_accuracy: 0.9146
# Epoch 106: Learning rate is 0.0018530200468376279.
# Epoch 106/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 0.9924 - val_loss: 0.3524 - val_accuracy: 0.9196
# Epoch 107: Learning rate is 0.0018530200468376279.
# Epoch 107/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9937 - val_loss: 0.3587 - val_accuracy: 0.9146
# Epoch 108: Learning rate is 0.0018530200468376279.
# Epoch 108/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9924 - val_loss: 0.3623 - val_accuracy: 0.9095
# Epoch 109: Learning rate is 0.0018530200468376279.
# Epoch 109/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9937 - val_loss: 0.3552 - val_accuracy: 0.9095
# Epoch 110: Learning rate is 0.0018530200468376279.
# Epoch 110/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 00110: ReduceLROnPlateau reducing learning rate to 0.0016677180421538651.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9924 - val_loss: 0.3641 - val_accuracy: 0.9045
# Epoch 111: Learning rate is 0.0016677180537953973.
# Epoch 111/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9937 - val_loss: 0.3625 - val_accuracy: 0.9146
# Epoch 112: Learning rate is 0.0016677180537953973.
# Epoch 112/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0375 - accuracy: 0.9937 - val_loss: 0.3575 - val_accuracy: 0.9146
# Epoch 113: Learning rate is 0.0016677180537953973.
# Epoch 113/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0375 - accuracy: 0.9937 - val_loss: 0.3647 - val_accuracy: 0.9095
# Epoch 114: Learning rate is 0.0016677180537953973.
# Epoch 114/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0373 - accuracy: 0.9924 - val_loss: 0.3648 - val_accuracy: 0.9146
# Epoch 115: Learning rate is 0.0016677180537953973.
# Epoch 115/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 0.0015009462484158575.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0413 - accuracy: 0.9937 - val_loss: 0.3643 - val_accuracy: 0.9146
# Epoch 116: Learning rate is 0.0015009462367743254.
# Epoch 116/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9937 - val_loss: 0.3825 - val_accuracy: 0.9095
# Epoch 117: Learning rate is 0.0015009462367743254.
# Epoch 117/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0372 - accuracy: 0.9937 - val_loss: 0.3620 - val_accuracy: 0.9196
# Epoch 118: Learning rate is 0.0015009462367743254.
# Epoch 118/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0367 - accuracy: 0.9937 - val_loss: 0.3764 - val_accuracy: 0.9146
# Epoch 119: Learning rate is 0.0015009462367743254.
# Epoch 119/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9937 - val_loss: 0.3687 - val_accuracy: 0.9146
# Epoch 120: Learning rate is 0.0015009462367743254.
# Epoch 120/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0127 - accuracy: 1.0000
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 0.0013508516130968928.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 0.9949 - val_loss: 0.3679 - val_accuracy: 0.9196
# Epoch 121: Learning rate is 0.0013508516130968928.
# Epoch 121/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9949 - val_loss: 0.3709 - val_accuracy: 0.9146
# Epoch 122: Learning rate is 0.0013508516130968928.
# Epoch 122/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9949 - val_loss: 0.3735 - val_accuracy: 0.9146
# Epoch 123: Learning rate is 0.0013508516130968928.
# Epoch 123/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9937 - val_loss: 0.3767 - val_accuracy: 0.9146
# Epoch 124: Learning rate is 0.0013508516130968928.
# Epoch 124/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 0.9949 - val_loss: 0.3805 - val_accuracy: 0.9095
# Epoch 125: Learning rate is 0.0013508516130968928.
# Epoch 125/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 0.0012157664517872036.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9924 - val_loss: 0.3707 - val_accuracy: 0.9196
# Epoch 126: Learning rate is 0.001215766416862607.
# Epoch 126/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9937 - val_loss: 0.3817 - val_accuracy: 0.9095
# Epoch 127: Learning rate is 0.001215766416862607.
# Epoch 127/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9937 - val_loss: 0.3789 - val_accuracy: 0.9146
# Epoch 128: Learning rate is 0.001215766416862607.
# Epoch 128/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 0.9949 - val_loss: 0.3778 - val_accuracy: 0.9196
# Epoch 129: Learning rate is 0.001215766416862607.
# Epoch 129/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9937 - val_loss: 0.3883 - val_accuracy: 0.9095
# Epoch 130: Learning rate is 0.001215766416862607.
# Epoch 130/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0141 - accuracy: 1.0000
# Epoch 00130: ReduceLROnPlateau reducing learning rate to 0.0010941897751763463.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9949 - val_loss: 0.3836 - val_accuracy: 0.9196
# Epoch 131: Learning rate is 0.001094189821742475.
# Epoch 131/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 0.9937 - val_loss: 0.3810 - val_accuracy: 0.9196
# Epoch 132: Learning rate is 0.001094189821742475.
# Epoch 132/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0334 - accuracy: 0.9949 - val_loss: 0.3853 - val_accuracy: 0.9146
# Epoch 133: Learning rate is 0.001094189821742475.
# Epoch 133/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9937 - val_loss: 0.3781 - val_accuracy: 0.9196
# Epoch 134: Learning rate is 0.001094189821742475.
# Epoch 134/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9924 - val_loss: 0.3879 - val_accuracy: 0.9095
# Epoch 135: Learning rate is 0.001094189821742475.
# Epoch 135/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0753 - accuracy: 0.9844Restoring model weights from the end of the best epoch.
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 0.0009847708395682275.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 0.9924 - val_loss: 0.3906 - val_accuracy: 0.9146
# Epoch 00135: early stopping

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 8/8 [==============================] - 0s 374us/step - loss: 0.4142 - accuracy: 0.8911
# Test accuracy: 0.8911290168762207
# Test loss: 0.41421881318092346

# %%
# Plotting the training and validation loss
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# Plotting
# plt.figure(figsize=(8, 8))
plt.plot(lr_tracker.learning_rates)
plt.title("Learning Rate over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.grid(True)

# %%
# Save the model
tf.keras.models.save_model(model, 'exo_model')
# Out:
# INFO:tensorflow:Assets written to: exo_model\assets

# %%
from tensorflow.keras.models import Model

# model.summary()
# Assume 'original_model' is your pre-trained model
model_without_softmax = Model(inputs=model.input, 
                              outputs=model.get_layer("dense_2").output)
model_without_softmax.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_0_input (InputLayer)   [(None, 63)]              0
# _________________________________________________________________
# dense_0 (Dense)              (None, 128)               8192
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 16,643
# Trainable params: 16,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the model
tf.keras.models.save_model(model_without_softmax, 'exo_model_without_softmax')
# Out:
# INFO:tensorflow:Assets written to: exo_model_without_softmax\assets
