# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# List all physical devices
physical_devices = tf.config.list_physical_devices()
print("Physical devices:", physical_devices)

# Check for GPU specifically
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU is available.")
else:
    print("GPU is NOT available.")
# Out:
# Physical devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# GPU is NOT available.

# %%
# Load your dataset
dataset = pd.read_csv('Dataset.csv')  # Replace with your dataset path
dataset.iloc[:, -1] = dataset.iloc[:, -1] - 1
X = dataset.iloc[:, :-1]  # Features
y = dataset.iloc[:, -1]   # Target

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert labels to categorical
y_categorical = to_categorical(y)

# Shuffle the data
X_scaled, y_categorical = shuffle(X_scaled, y_categorical, random_state=42)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42)

# Number of unique classes in the target variable
num_classes = y_train.shape[1]


# Building the DNN model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')  # Output layer
])

# %%
# Define the early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,  # minimium amount of change to count as an improvement
    patience=100,  # how many epochs to wait before stopping
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# Set the learning rate
learning_rate = 0.01

# Create the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.9,  # factor by which the learning rate will be reduced
    patience=5,  # number of epochs with no improvement after which learning rate will be reduced
    min_lr=0.00001,  # lower bound on the learning rate
    verbose=1
)
lr_callback = tf.keras.callbacks.LearningRateScheduler(reduce_lr)

class PrintLR(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.learning_rates = []
        
    def on_epoch_begin(self, epoch, logs=None):
        lr = self.model.optimizer.lr
        if hasattr(lr, 'numpy'):
            lr = lr.numpy()
        elif hasattr(lr, 'eval'):
            lr = lr.eval(session=tf.compat.v1.Session())
        print(f'Epoch {epoch+1}: Learning rate is {lr}.')
    
    def on_epoch_end(self, epoch, logs=None):
        # Retrieve the current learning rate from the optimizer
        current_lr = tf.keras.backend.get_value(self.model.optimizer.lr)
        # Append the current learning rate to the list
        self.learning_rates.append(current_lr)

lr_tracker = PrintLR()
callbacks = [lr_tracker, early_stopping, reduce_lr]


# Initialize the optimizer with the learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compiling the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Pass the callback to the fit method
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=1000,
    batch_size=64,
    callbacks=callbacks  # include it here
)
# Out:
# Epoch 1: Learning rate is 0.009999999776482582.
# Epoch 1/1000
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5753 - accuracy: 0.7121 - val_loss: 0.4029 - val_accuracy: 0.7688
# Epoch 2: Learning rate is 0.009999999776482582.
# Epoch 2/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.7639 - val_loss: 0.3851 - val_accuracy: 0.7839
# Epoch 3: Learning rate is 0.009999999776482582.
# Epoch 3/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3625 - accuracy: 0.8119 - val_loss: 0.5324 - val_accuracy: 0.7739
# Epoch 4: Learning rate is 0.009999999776482582.
# Epoch 4/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3544 - accuracy: 0.8093 - val_loss: 0.3816 - val_accuracy: 0.8191
# Epoch 5: Learning rate is 0.009999999776482582.
# Epoch 5/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3385 - accuracy: 0.8308 - val_loss: 0.3732 - val_accuracy: 0.8392
# Epoch 6: Learning rate is 0.009999999776482582.
# Epoch 6/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.8396 - val_loss: 0.3720 - val_accuracy: 0.8141
# Epoch 7: Learning rate is 0.009999999776482582.
# Epoch 7/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.8321 - val_loss: 0.3492 - val_accuracy: 0.8442
# Epoch 8: Learning rate is 0.009999999776482582.
# Epoch 8/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.8649 - val_loss: 0.4709 - val_accuracy: 0.7789
# Epoch 9: Learning rate is 0.009999999776482582.
# Epoch 9/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.8636 - val_loss: 0.3665 - val_accuracy: 0.8191
# Epoch 10: Learning rate is 0.009999999776482582.
# Epoch 10/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2460 - accuracy: 0.8801 - val_loss: 0.3756 - val_accuracy: 0.8543
# Epoch 11: Learning rate is 0.009999999776482582.
# Epoch 11/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.8864 - val_loss: 0.3950 - val_accuracy: 0.8090
# Epoch 12: Learning rate is 0.009999999776482582.
# Epoch 12/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2871 - accuracy: 0.8438
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.008999999798834325.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2373 - accuracy: 0.8939 - val_loss: 0.3973 - val_accuracy: 0.8593
# Epoch 13: Learning rate is 0.008999999612569809.
# Epoch 13/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2152 - accuracy: 0.9066 - val_loss: 0.4001 - val_accuracy: 0.8543
# Epoch 14: Learning rate is 0.008999999612569809.
# Epoch 14/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2178 - accuracy: 0.8914 - val_loss: 0.5197 - val_accuracy: 0.7487
# Epoch 15: Learning rate is 0.008999999612569809.
# Epoch 15/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2624 - accuracy: 0.8737 - val_loss: 0.3956 - val_accuracy: 0.8492
# Epoch 16: Learning rate is 0.008999999612569809.
# Epoch 16/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2495 - accuracy: 0.8737 - val_loss: 0.3704 - val_accuracy: 0.8141
# Epoch 17: Learning rate is 0.008999999612569809.
# Epoch 17/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.3076 - accuracy: 0.8281
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.008099999651312828.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.2133 - accuracy: 0.9104 - val_loss: 0.3699 - val_accuracy: 0.8593
# Epoch 18: Learning rate is 0.008099999278783798.
# Epoch 18/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.9116 - val_loss: 0.3655 - val_accuracy: 0.8593
# Epoch 19: Learning rate is 0.008099999278783798.
# Epoch 19/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1738 - accuracy: 0.9230 - val_loss: 0.4889 - val_accuracy: 0.8492
# Epoch 20: Learning rate is 0.008099999278783798.
# Epoch 20/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9255 - val_loss: 0.3969 - val_accuracy: 0.8643
# Epoch 21: Learning rate is 0.008099999278783798.
# Epoch 21/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1539 - accuracy: 0.9407 - val_loss: 0.4692 - val_accuracy: 0.8693
# Epoch 22: Learning rate is 0.008099999278783798.
# Epoch 22/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.2225 - accuracy: 0.9062
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.007289999350905419.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1434 - accuracy: 0.9381 - val_loss: 0.4927 - val_accuracy: 0.8693
# Epoch 23: Learning rate is 0.0072899991646409035.
# Epoch 23/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1268 - accuracy: 0.9419 - val_loss: 0.4531 - val_accuracy: 0.8593
# Epoch 24: Learning rate is 0.0072899991646409035.
# Epoch 24/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1274 - accuracy: 0.9470 - val_loss: 0.4578 - val_accuracy: 0.8492
# Epoch 25: Learning rate is 0.0072899991646409035.
# Epoch 25/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1625 - accuracy: 0.9331 - val_loss: 0.4915 - val_accuracy: 0.8693
# Epoch 26: Learning rate is 0.0072899991646409035.
# Epoch 26/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1407 - accuracy: 0.9444 - val_loss: 0.5715 - val_accuracy: 0.8744
# Epoch 27: Learning rate is 0.0072899991646409035.
# Epoch 27/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1300 - accuracy: 0.9531
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.006560999248176813.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9495 - val_loss: 0.5368 - val_accuracy: 0.8593
# Epoch 28: Learning rate is 0.006560999434441328.
# Epoch 28/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.9545 - val_loss: 0.5569 - val_accuracy: 0.8392
# Epoch 29: Learning rate is 0.006560999434441328.
# Epoch 29/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1462 - accuracy: 0.9293 - val_loss: 0.5277 - val_accuracy: 0.8492
# Epoch 30: Learning rate is 0.006560999434441328.
# Epoch 30/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1305 - accuracy: 0.9432 - val_loss: 0.6195 - val_accuracy: 0.8593
# Epoch 31: Learning rate is 0.006560999434441328.
# Epoch 31/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1318 - accuracy: 0.9457 - val_loss: 0.5533 - val_accuracy: 0.8543
# Epoch 32: Learning rate is 0.006560999434441328.
# Epoch 32/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.1008 - accuracy: 0.9531
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.005904899490997195.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1119 - accuracy: 0.9533 - val_loss: 0.6600 - val_accuracy: 0.8492
# Epoch 33: Learning rate is 0.0059048994444310665.
# Epoch 33/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9495 - val_loss: 0.5711 - val_accuracy: 0.8794
# Epoch 34: Learning rate is 0.0059048994444310665.
# Epoch 34/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9609 - val_loss: 0.6216 - val_accuracy: 0.8693
# Epoch 35: Learning rate is 0.0059048994444310665.
# Epoch 35/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.9659 - val_loss: 0.7130 - val_accuracy: 0.8693
# Epoch 36: Learning rate is 0.0059048994444310665.
# Epoch 36/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9634 - val_loss: 0.6052 - val_accuracy: 0.8744
# Epoch 37: Learning rate is 0.0059048994444310665.
# Epoch 37/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0573 - accuracy: 0.9688
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00531440949998796.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9470 - val_loss: 0.7652 - val_accuracy: 0.8191
# Epoch 38: Learning rate is 0.0053144097328186035.
# Epoch 38/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.1095 - accuracy: 0.9520 - val_loss: 0.6740 - val_accuracy: 0.8693
# Epoch 39: Learning rate is 0.0053144097328186035.
# Epoch 39/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0903 - accuracy: 0.9659 - val_loss: 0.6221 - val_accuracy: 0.8894
# Epoch 40: Learning rate is 0.0053144097328186035.
# Epoch 40/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9646 - val_loss: 0.6415 - val_accuracy: 0.8693
# Epoch 41: Learning rate is 0.0053144097328186035.
# Epoch 41/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 0.9659 - val_loss: 0.6128 - val_accuracy: 0.8643
# Epoch 42: Learning rate is 0.0053144097328186035.
# Epoch 42/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0435 - accuracy: 0.9688
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.004782968759536744.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0661 - accuracy: 0.9735 - val_loss: 0.6705 - val_accuracy: 0.8693
# Epoch 43: Learning rate is 0.004782968666404486.
# Epoch 43/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0615 - accuracy: 0.9773 - val_loss: 0.6337 - val_accuracy: 0.8794
# Epoch 44: Learning rate is 0.004782968666404486.
# Epoch 44/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9773 - val_loss: 0.7352 - val_accuracy: 0.8744
# Epoch 45: Learning rate is 0.004782968666404486.
# Epoch 45/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0685 - accuracy: 0.9735 - val_loss: 0.7226 - val_accuracy: 0.8794
# Epoch 46: Learning rate is 0.004782968666404486.
# Epoch 46/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 0.9710 - val_loss: 0.7065 - val_accuracy: 0.8693
# Epoch 47: Learning rate is 0.004782968666404486.
# Epoch 47/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0384 - accuracy: 0.9844
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0043046717997640375.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0655 - accuracy: 0.9722 - val_loss: 0.6047 - val_accuracy: 0.8693
# Epoch 48: Learning rate is 0.004304671660065651.
# Epoch 48/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9747 - val_loss: 0.6886 - val_accuracy: 0.8794
# Epoch 49: Learning rate is 0.004304671660065651.
# Epoch 49/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0586 - accuracy: 0.9773 - val_loss: 0.6402 - val_accuracy: 0.8844
# Epoch 50: Learning rate is 0.004304671660065651.
# Epoch 50/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0577 - accuracy: 0.9760 - val_loss: 0.6263 - val_accuracy: 0.8894
# Epoch 51: Learning rate is 0.004304671660065651.
# Epoch 51/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9798 - val_loss: 0.6744 - val_accuracy: 0.8894
# Epoch 52: Learning rate is 0.004304671660065651.
# Epoch 52/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0404 - accuracy: 0.9844
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0038742044940590858.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0620 - accuracy: 0.9747 - val_loss: 0.7353 - val_accuracy: 0.8693
# Epoch 53: Learning rate is 0.0038742045871913433.
# Epoch 53/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9836 - val_loss: 0.7150 - val_accuracy: 0.8794
# Epoch 54: Learning rate is 0.0038742045871913433.
# Epoch 54/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9848 - val_loss: 0.7401 - val_accuracy: 0.8794
# Epoch 55: Learning rate is 0.0038742045871913433.
# Epoch 55/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9823 - val_loss: 0.7413 - val_accuracy: 0.8995
# Epoch 56: Learning rate is 0.0038742045871913433.
# Epoch 56/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0404 - accuracy: 0.9861 - val_loss: 0.7742 - val_accuracy: 0.8995
# Epoch 57: Learning rate is 0.0038742045871913433.
# Epoch 57/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0607 - accuracy: 0.9844
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9848 - val_loss: 0.7874 - val_accuracy: 0.9095
# Epoch 58: Learning rate is 0.0034867841750383377.
# Epoch 58/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9886 - val_loss: 0.7057 - val_accuracy: 0.9045
# Epoch 59: Learning rate is 0.0034867841750383377.
# Epoch 59/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0374 - accuracy: 0.9861 - val_loss: 0.8539 - val_accuracy: 0.8794
# Epoch 60: Learning rate is 0.0034867841750383377.
# Epoch 60/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9874 - val_loss: 0.7610 - val_accuracy: 0.8894
# Epoch 61: Learning rate is 0.0034867841750383377.
# Epoch 61/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9811 - val_loss: 0.7746 - val_accuracy: 0.8945
# Epoch 62: Learning rate is 0.0034867841750383377.
# Epoch 62/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0266 - accuracy: 0.9844
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.003138105757534504.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0730 - accuracy: 0.9798 - val_loss: 0.6162 - val_accuracy: 0.9045
# Epoch 63: Learning rate is 0.0031381058506667614.
# Epoch 63/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9848 - val_loss: 0.6497 - val_accuracy: 0.8945
# Epoch 64: Learning rate is 0.0031381058506667614.
# Epoch 64/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 0.9899 - val_loss: 0.6688 - val_accuracy: 0.8995
# Epoch 65: Learning rate is 0.0031381058506667614.
# Epoch 65/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0526 - accuracy: 0.9773 - val_loss: 0.7530 - val_accuracy: 0.8794
# Epoch 66: Learning rate is 0.0031381058506667614.
# Epoch 66/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9836 - val_loss: 0.6478 - val_accuracy: 0.8945
# Epoch 67: Learning rate is 0.0031381058506667614.
# Epoch 67/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0028242952656000854.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 0.9886 - val_loss: 0.7151 - val_accuracy: 0.8995
# Epoch 68: Learning rate is 0.002824295312166214.
# Epoch 68/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9886 - val_loss: 0.7258 - val_accuracy: 0.8995
# Epoch 69: Learning rate is 0.002824295312166214.
# Epoch 69/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 0.9848 - val_loss: 0.7103 - val_accuracy: 0.9045
# Epoch 70: Learning rate is 0.002824295312166214.
# Epoch 70/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0344 - accuracy: 0.9848 - val_loss: 0.6900 - val_accuracy: 0.8995
# Epoch 71: Learning rate is 0.002824295312166214.
# Epoch 71/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0244 - accuracy: 0.9899 - val_loss: 0.7597 - val_accuracy: 0.8945
# Epoch 72: Learning rate is 0.002824295312166214.
# Epoch 72/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0156 - accuracy: 1.0000
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.0025418657809495927.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.7215 - val_accuracy: 0.8995
# Epoch 73: Learning rate is 0.002541865687817335.
# Epoch 73/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 0.9912 - val_loss: 0.7531 - val_accuracy: 0.9045
# Epoch 74: Learning rate is 0.002541865687817335.
# Epoch 74/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0208 - accuracy: 0.9962 - val_loss: 0.7609 - val_accuracy: 0.9045
# Epoch 75: Learning rate is 0.002541865687817335.
# Epoch 75/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.7882 - val_accuracy: 0.8995
# Epoch 76: Learning rate is 0.002541865687817335.
# Epoch 76/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9962 - val_loss: 0.8246 - val_accuracy: 0.8945
# Epoch 77: Learning rate is 0.002541865687817335.
# Epoch 77/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.0022876791190356016.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 0.9924 - val_loss: 0.8091 - val_accuracy: 0.8995
# Epoch 78: Learning rate is 0.0022876791190356016.
# Epoch 78/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.7934 - val_accuracy: 0.8945
# Epoch 79: Learning rate is 0.0022876791190356016.
# Epoch 79/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 0.9886 - val_loss: 0.8176 - val_accuracy: 0.9045
# Epoch 80: Learning rate is 0.0022876791190356016.
# Epoch 80/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9962 - val_loss: 0.8712 - val_accuracy: 0.8894
# Epoch 81: Learning rate is 0.0022876791190356016.
# Epoch 81/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.8293 - val_accuracy: 0.9095
# Epoch 82: Learning rate is 0.0022876791190356016.
# Epoch 82/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0020589112071320416.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9912 - val_loss: 0.8456 - val_accuracy: 0.8995
# Epoch 83: Learning rate is 0.0020589111372828484.
# Epoch 83/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9924 - val_loss: 0.8677 - val_accuracy: 0.9045
# Epoch 84: Learning rate is 0.0020589111372828484.
# Epoch 84/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.9140 - val_accuracy: 0.8945
# Epoch 85: Learning rate is 0.0020589111372828484.
# Epoch 85/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9899 - val_loss: 0.8181 - val_accuracy: 0.8945
# Epoch 86: Learning rate is 0.0020589111372828484.
# Epoch 86/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.9912 - val_loss: 0.8286 - val_accuracy: 0.9045
# Epoch 87: Learning rate is 0.0020589111372828484.
# Epoch 87/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.0018530200235545636.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9924 - val_loss: 0.9193 - val_accuracy: 0.8945
# Epoch 88: Learning rate is 0.0018530200468376279.
# Epoch 88/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.8867 - val_accuracy: 0.8945
# Epoch 89: Learning rate is 0.0018530200468376279.
# Epoch 89/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9975 - val_loss: 0.8602 - val_accuracy: 0.8995
# Epoch 90: Learning rate is 0.0018530200468376279.
# Epoch 90/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.9290 - val_accuracy: 0.8945
# Epoch 91: Learning rate is 0.0018530200468376279.
# Epoch 91/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.9194 - val_accuracy: 0.8995
# Epoch 92: Learning rate is 0.0018530200468376279.
# Epoch 92/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.0016677180421538651.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.8949 - val_accuracy: 0.8995
# Epoch 93: Learning rate is 0.0016677180537953973.
# Epoch 93/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9359 - val_accuracy: 0.8995
# Epoch 94: Learning rate is 0.0016677180537953973.
# Epoch 94/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.9276 - val_accuracy: 0.9095
# Epoch 95: Learning rate is 0.0016677180537953973.
# Epoch 95/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0115 - accuracy: 0.9949 - val_loss: 0.9408 - val_accuracy: 0.9045
# Epoch 96: Learning rate is 0.0016677180537953973.
# Epoch 96/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.9474 - val_accuracy: 0.9045
# Epoch 97: Learning rate is 0.0016677180537953973.
# Epoch 97/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 0.0015009462484158575.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0429 - accuracy: 0.9874 - val_loss: 0.8495 - val_accuracy: 0.8894
# Epoch 98: Learning rate is 0.0015009462367743254.
# Epoch 98/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.9848 - val_loss: 0.9697 - val_accuracy: 0.8894
# Epoch 99: Learning rate is 0.0015009462367743254.
# Epoch 99/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0232 - accuracy: 0.9949 - val_loss: 0.9241 - val_accuracy: 0.8995
# Epoch 100: Learning rate is 0.0015009462367743254.
# Epoch 100/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9949 - val_loss: 0.8351 - val_accuracy: 0.8995
# Epoch 101: Learning rate is 0.0015009462367743254.
# Epoch 101/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.9249 - val_accuracy: 0.8995
# Epoch 102: Learning rate is 0.0015009462367743254.
# Epoch 102/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 0.0013508516130968928.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.8825 - val_accuracy: 0.9095
# Epoch 103: Learning rate is 0.0013508516130968928.
# Epoch 103/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9962 - val_loss: 0.8854 - val_accuracy: 0.9045
# Epoch 104: Learning rate is 0.0013508516130968928.
# Epoch 104/1000
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 0.9129 - val_accuracy: 0.8945
# Epoch 105: Learning rate is 0.0013508516130968928.
# Epoch 105/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.9214 - val_accuracy: 0.8945
# Epoch 106: Learning rate is 0.0013508516130968928.
# Epoch 106/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.9987 - val_loss: 0.9219 - val_accuracy: 0.8995
# Epoch 107: Learning rate is 0.0013508516130968928.
# Epoch 107/1000
#  1/13 [=>............................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000Restoring model weights from the end of the best epoch.
#
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 0.0012157664517872036.
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.9987 - val_loss: 0.9255 - val_accuracy: 0.8995
# Epoch 00107: early stopping

# %%
# Evaluating the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# 8/8 [==============================] - 0s 499us/step - loss: 0.3154 - accuracy: 0.8629
# Test accuracy: 0.8629032373428345
# Test loss: 0.31538939476013184

# %%
# Plotting the training and validation loss
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# Plotting
# plt.figure(figsize=(8, 8))
plt.plot(lr_tracker.learning_rates)
plt.title("Learning Rate over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.grid(True)

# %%
# Save the model
tf.keras.models.save_model(model, 'exo_model')
# Out:
# WARNING:tensorflow:From C:\Users\shinm\miniconda3\envs\tf23\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\shinm\miniconda3\envs\tf23\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: exo_model\assets

# %%
from tensorflow.keras.models import Model

# model.summary()
# Assume 'original_model' is your pre-trained model
model_without_softmax = Model(inputs=model.input, 
                              outputs=model.get_layer("dense_58").output)

# %%
# Save the model
tf.keras.models.save_model(model, 'exo_model_without_softmax')
# Out:
# INFO:tensorflow:Assets written to: exo_model_without_softmax\assets
